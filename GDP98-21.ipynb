# %%
import pandas as pd
GDP9821 = pd.read_excel('GDP98-21.xlsx')

# %%
df.head()
# Out:
#         date  reference  England  Wales  Scotland  Northern Ireland  \
# 0 1999-01-01        3.0      3.8    2.6       2.0               4.3
# 1 2000-01-01        4.1      4.5    3.8       3.2               6.1
# 2 2001-01-01        2.2      1.9    2.0       2.9               1.9
# 3 2002-01-01        1.8      1.7    1.5       1.4               0.7
# 4 2003-01-01        3.1      3.2    3.6       2.9               4.3
#
#    North East  North West  Yorkshire and The Humber  East Midlands  \
# 0         2.5         4.1                       3.4            3.0
# 1         2.7         2.2                       3.1            2.9
# 2         4.1         3.2                       3.0            2.2
# 3         4.0         2.3                       3.0            1.1
# 4         3.6         3.3                       4.2            3.1
#
#    West Midlands  East  London  South East  South West
# 0            3.5   3.9     4.1         4.4         3.8
# ...

# %%
other_regions_data = df.drop(columns=['South West'])


mean_growth_other_regions = other_regions_data.mean()

plt.figure(figsize=(14, 7))
for column in other_regions_data.columns:
    plt.plot(other_regions_data.index, other_regions_data[column], label=column, marker='o')

plt.title('GDP Growth Rate Trends for All Regions Except South West')
plt.xlabel('Year')
plt.ylabel('GDP Growth Rate (%)')
plt.legend()
plt.grid(True)
plt.show()

# Comparative
mean_growth_other_regions.plot(kind='bar', title='Mean GDP Growth Rate by Region (Excluding South West)')
plt.xlabel('Region')
plt.ylabel('Mean GDP Growth Rate (%)')
plt.xticks(rotation=45)
plt.tight_layout()  
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['reference', 'England', 'Wales', 'Scotland', 'Northern Ireland', 'North East', 'North West', 'Yorkshire and The Humber', 'East Midlands', 'West Midlands', 'East', 'London', 'South East', 'South West']

# %%
# Isolate the South West data
south_west_data = df[['South West']]  # Assuming 'South West' is the correct column name

# Plotting the South West trend
plt.figure(figsize=(14, 7))
plt.plot(south_west_data.index, south_west_data['South West'], label='South West', marker='o', color='blue')
plt.title('GDP Growth Rate Trend for South West')
plt.xlabel('Year')
plt.ylabel('GDP Growth Rate (%)')
plt.legend()
plt.grid(True)
plt.show()
