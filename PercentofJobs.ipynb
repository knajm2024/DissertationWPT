# %%
# !pip install xlrd
import pandas as pd 
jobs = pd.read_excel('Jobpercentage.xls')
# Out:
# ...
#   Obtaining dependency information for xlrd from https://files.pythonhosted.org/packages/a6/0c/c2a72d51fe56e08a08acc85d13013558a2d793028ae7385448a6ccdfae64/xlrd-2.0.1-py2.py3-none-any.whl.metadata
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# ...
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/8a/6a/19e9fe04fca059ccf770861c7d5721ab4c2aebc539889e97c7977528a53b/pip-24.0-py3-none-any.whl.metadata
#   Using cached pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.0-py3-none-any.whl (2.1 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
jobs = pd.read_excel('Jobpercentage.xls')

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = {
    'Region': ['Devon', 'Cornwall'],
    'Accommodation': [25.9, 34],
    'Food and Beverage': [42.2, 35.9],
    'Transport': [10.9, 9],
    'Cultural Activities': [21.1, 21.1]
}
df = pd.DataFrame(data)


df.set_index('Region', inplace=True)

# Plotting
df.plot(kind='bar', figsize=(10, 7))
plt.title('The percentage of jobs in the four different tourism industry sectors')
plt.ylabel('% Distribution')
plt.xlabel('Region')
plt.xticks(rotation=45)
plt.legend(title='Activity Type')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = {
    'Region': [
        'Bath and North East Somerset', 'Bournemouth', 'Brighton and Hove', 'Cardiff',
        'Carmarthenshire', 'Ceredigion', 'Conwy', 'Cornwall', 'Cumbria', 'Denbighshire',
        'Devon', 'Dorset', 'East Sussex', 'Greater London', 'Gwynedd', 'Hartlepool',
        'Isle of Anglesey', 'Isle of Wight', 'Norfolk', 'North Somerset', 'North Yorkshire',
        'Northumberland', 'Oldham', 'Pembrokeshire', 'Poole', 'Powys', 'Somerset', 'Suffolk',
        'Torbay', 'Wiltshire', 'York'
    ],
    'Accommodation': [
        12.5, 16.1, 6.3, 10.3, 16.3, 24.3, 25.9, 34, 34.9, 23.7,
        25.9, 23.8, 13.5, 8.8, 35.2, 13.4, 22.1, 31, 24.5, 13, 22.4,
        17.4, 6.4, 36.4, 15.1, 19.4, 18.1, 14.2, 32.8, 16.7, 13.5
    ],
    'Food and Beverage': [
        51.1, 42.4, 49.1, 41.4, 45.8, 36.4, 44.7, 35.9, 38, 40,
        42.2, 39.3, 34.4, 36.7, 34.3, 57, 41.2, 34.6, 38.4, 61.9, 46.6,
        48.1, 59.5, 33.2, 38.1, 34.1, 46.1, 39.6, 33.1, 43.3, 43.5
    ],
    'Transport': [
        11.8, 18.8, 15.8, 14, 6.9, 9.6, 9.7, 9, 12.6, 14.4,
        10.9, 10.3, 10.7, 24.1, 6, 11.6, 20.4, 9.6, 10.6, 8.6, 10.9,
        15.4, 21.1, 11.6, 20.9, 12.9, 7.1, 15.8, 9.7, 11, 20.5
    ],
    'Cultural Activities': [
        24.6, 22.8, 28.8, 34.3, 31, 29.7, 19.7, 21.1, 14.6, 21.9,
        21.1, 26.6, 41.4, 30.4, 24.5, 18, 16.2, 24.8, 26.5, 16.5, 20.1,
        19.1, 12.9, 18.8, 25.9, 33.6, 28.7, 30.4, 24.5, 29, 22.5
    ]
}

df = pd.DataFrame(data)
df.set_index('Region', inplace=True)

# Exclude Devon and Cornwall
df_filtered = df.drop(['Devon', 'Cornwall'])


plt.figure(figsize=(10, 15))  
df.plot(kind='barh', stacked=True, legend='reverse')  

plt.title('Tourism Activity Distribution by Region (Excluding Devon and Cornwall)')
plt.xlabel('Distribution (%)')
plt.ylabel('Region')
plt.legend(title='Activity Type')
plt.tight_layout() 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 18))  
ax = df.plot(kind='barh', stacked=True, figsize=(12, 18)) 

plt.title('Tourism Activity Distribution by Region (Excluding Devon and Cornwall)')
plt.xlabel('Distribution (%)')
plt.ylabel('Region')

plt.legend(title='Activity Type', bbox_to_anchor=(1.2, 1), loc='upper left')


plt.subplots_adjust(left=0.2, right=0.8, top=0.95, bottom=0.05) 

plt.show()

# %%
print(jobs.head())
# Out:
#   Figure 1: The percentage of jobs in the four different tourism industry sectors, for locations in clusters 4 and 5  \
# 0                                                NaN
# 1                                                NaN
# 2                                              Notes
# 3                                               Unit
# 4                                                NaN
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN
# 3          %        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN

# %%
print(jobs.isnull().sum())

jobs.fillna(method='ffill', inplace=True)
# Out:
# Figure 1: The percentage of jobs in the four different tourism industry sectors, for locations in clusters 4 and 5    4
# Unnamed: 1                                                                                                            4
# Unnamed: 2                                                                                                            5
# Unnamed: 3                                                                                                            5
# Unnamed: 4                                                                                                            5
# dtype: int64

# %%
correlation_matrix = jobs[['Accommodation for visitors', 'Food and beverage service activities', 'Passenger transport, travel agencies, vehicle hire etc', 'Cultural, sport, recreational and conference activities']].corr()

print(correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Calculate the correlation matrix
# ----> 2 correlation_matrix = jobs[['Accommodation for visitors', 'Food and beverage service activities', 'Passenger transport, travel agencies, vehicle hire etc', 'Cultural, sport, recreational and conference activities']].corr()
#       4 print(correlation_matrix)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
# ...

# %%
print(jobs.columns)
# Out:
# Index(['Figure 1: The percentage of jobs in the four different tourism industry sectors, for locations in clusters 4 and 5',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],
#       dtype='object')

# %%
correlation_matrix = df[['Accommodation for visitors', 'Food and beverage service activities', 'Passenger transport, travel agencies, vehicle hire etc', 'Cultural, sport, recreational and conference activities']].corr()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 correlation_matrix = df[['Figure 1: The percentage of jobs in the four different tourism industry sectors, for locations in clusters 4 and 5',
#       2        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']].corr()
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
# ...
